# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivaram951577/FMML_LABS_ASSIGNMENTS_PROJECTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-15 11:06:33--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   203MB/s    in 0.3s
#
# 2024-05-15 11:06:37 (203 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 32613   1409.0923v1  This paper presents a new similarity measure t...    cs
# 8231    1404.1561v2  Supervised hashing aims to map the original fe...    cs
# 13239  cs/0212019v1  Ever increasing computational power will requi...    cs
# 19931   1303.5421v1  The paper describes aHUGIN, a tool for creatin...    cs
# 32364  1503.00491v1  \emph{Semi-Automated Text Classification} (SAT...    cs
# ...             ...                                                ...   ...
# 22439  1607.01369v3  Given a graph in which a few vertices are deem...  stat
# 22968  1711.11053v1  We propose a framework for general probabilist...  stat
# 39579  1609.06536v2  We present a real-time deep learning framework...    cs
# 33466   1212.0170v1  With the increasing number of intrusions in sy...    cs
# 2042    1301.6696v1  Learning Bayesian networks is often cast as an...    cs
#
#                                                    title  year  \
# 32613        Dimensionality Invariant Similarity Measure  2014
# 8231   Fast Supervised Hashing with Decision Trees fo...  2014
# 13239  Thinking, Learning, and Autonomous Problem Sol...  2002
# 19931  aHUGIN: A System Creating Adaptive Causal Prob...  2013
# 32364  Utility-Theoretic Ranking for Semi-Automated T...  2015
# ...                                                  ...   ...
# 22439  On the Consistency of the Likelihood Maximizat...  2016
# 22968      A Multi-Horizon Quantile Recurrent Forecaster  2017
# 39579  Production-Level Facial Performance Capture Us...  2016
# 33466  An Evolution Strategy Approach toward Rule-set...  2012
# 2042   Learning Bayesian Network Structure from Massi...  2013
#
#                                                 keywords
# 32613  [similarity, including, supervised, represente...
# 8231   [supervised, similarity, functions, demonstrat...
# 13239  [increasing, computational, automatic, program...
# 19931  [describes, extension, spiegelhalter, lauritze...
# 32364  [automated, classification, automatically, doc...
# ...                                                  ...
# 22439  [interesting, nomination, remaining, nominatio...
# 22968  [framework, probabilistic, regression, specifi...
# 39579  [framework, performance, monocular, accurately...
# 33466  [increasing, intrusions, infrastructures, intr...
# 2042   [optimization, computational, structure, maxim...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 32613    [similarity, including, supervised, represente...
# 8231     [supervised, similarity, functions, demonstrat...
# 13239    [increasing, computational, automatic, program...
# 19931    [describes, extension, spiegelhalter, lauritze...
# 32364    [automated, classification, automatically, doc...
#                                ...
# 23071    [simulation, multidimensional, processes, supe...
# 21609    [smoothing, regression, minimizer, penalized, ...
# 11112    [formulation, factorization, formulation, clus...
# 7465     [generative, impressive, empirically, essentia...
# 8459     [supervised, dictionary, algorithm, dimensions...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8763 words.
# Out of those 4540 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2a95b7d5-9b05-4615-870b-5ec1b009b948" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a95b7d5-9b05-4615-870b-5ec1b009b948")) {                    Plotly.newPlot(                        "2a95b7d5-9b05-4615-870b-5ec1b009b948",                        [{"x":["applications","classifying","promising","potential","represented","viability","invariant","experimental","dimensions","supervised","different","classifier","including","differences","dimensionality","mathematically","similarity","advantage","functions","significantly","evaluation","experiments","retrieval","generalization","dimensional","efficient","linearity","formulations","demonstrate","capability","performance","inference","outperforms","especially","encouraging","achieving","typically","precision","literature","demonstrated","magnitude","prototype","presented","philosophical","formalized","nonlinear","increasing","concentration","treatment","constructs","evolution","description","mathematical","autonomous","prototyping","structures","consideration","computational","differential","investigation","developed","implement","recognition","alternative","automatic","equations","application","programming","intuitive","extension","adaptation","described","discussed","describes","probabilistic","probabilities","lauritzen","spiegelhalter","resulting","partially","validating","effectiveness","labelling","theoretic","suboptimal","automated","automatically","improvement","confidence","annotator","substantially","reductions","validates","according","classification","reduction","generated","maximized","documents","implemented","information","instances","performed","architecture","comparison","addressing","integrating","representation","commonsense","relations","reasoning","qualitative","contemporary","constraints","satisfiability","currently","geographic","geometric","systematic","empirically","cognitive","polynomial","requirement","publication","monotonic","formalise","arithmetic","modelling","therefore","predictions","participants","additional","objective","solutions","positives","tomography","available","algorithms","validation","originally","annotated","convolutional","development","framework","challenge","excellent","candidates","detection","sensitivity","classified","combination","comparative","highlights","pulmonary","reference","algorithm","individual","investigated","combining","regularization","eigenvalues","generalized","associated","furthermore","techniques","localization","optimality","convergence","characterized","constantly","circumvent","approaches","considerably","themselves","artificial","filtering","specifically","neighbors","simplistic","dependencies","influence","experience","heterogeneous","conjunction","intelligent","prediction","probability","distribution","transitions","arbitrary","controlling","conditional","durations","synthetic","vehicular","predicting","transportation","parameters","conditions","influences"],"y":[457,46,125,157,94,4,77,374,47,210,760,172,246,56,49,16,150,98,217,239,273,558,106,100,188,401,8,16,551,54,894,203,245,108,17,78,100,63,125,94,61,23,163,4,8,64,106,10,32,19,57,69,60,52,4,136,24,284,41,42,206,69,351,107,175,27,270,122,29,91,59,71,60,84,147,66,2,2,145,54,6,225,5,46,17,81,161,157,48,7,34,3,5,109,522,90,182,4,72,95,706,103,111,250,135,23,48,354,9,104,117,53,13,143,20,48,7,57,38,72,46,57,34,8,11,2,11,62,157,87,11,126,160,141,12,20,320,578,52,11,75,367,125,544,161,36,35,343,29,33,146,39,23,3,60,819,129,54,119,94,7,61,109,143,385,70,25,122,29,4,5,478,22,18,135,55,188,23,3,53,50,37,34,24,67,247,163,221,13,73,15,101,3,143,4,72,9,237,129,13],"type":"bar"},{"x":["applications","classifying","promising","potential","represented","viabili ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4540,), (4540, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4835164835164835);'>Artificial</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>Symmetries</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differential</span> <span style='background-color:rgba(0, 255, 0, 0.3734939759036144);'>Evolution</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 1.0);'>Neuroevolution</span> <span style=''>is</span> <span style=''>an</span> <span style=''>active</span> <span style=''>and</span> <span style=''>growing</span> <span style=''>research</span> <span style=''>field</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>in</span> <span style=''>times</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasingly</span> <span style=''>parallel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style='background-color:rgba(0, 255, 0, 0.34117647058823525);'>architectures</span> <span style=''>Learning</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4835164835164835);'>Artificial</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(ANN)</span> <span style=''>can</span> <span style=''>be</span> <span style=''>divided</span> <span style=''>into</span> <span style=''>two</span> <span style=''>groups</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Neuroevolution</span> <span style=''>is</span> <span style=''>mainly</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>and</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>the</span> <span style=''>group</span> <span style=''>of</span> <span style=''>global</span> <span style=''>search</span> <span style=''>methods</span> <span style=''>whereas</span> <span style=''>other</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>backpropagation</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>the</span> <span style=''>group</span> <span style=''>of</span> <span style=''>local</span> <span style=''>search</span> <span style=''>methods</span> <span style=''>ANNs</span> <span style=''>comprise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>symmetry</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>which</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>methods</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>local</span> <span style=''>search</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unaffected</span> <span style=''>by</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>symmetries</span> <span style=''>In</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>symmetries</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>reported</span> <span style=''>as</span> <span style=''>being</span> <span style=''>not</span> <span style='background-color:rgba(0, 25 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scaling</span> <span style=''>up</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistician</span> <span style=''>Scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovery</span> <span style=''>using</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Automating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intelligence</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistician</span> <span style=''>takes</span> <span style=''>a</span> <span style=''>first</span> <span style=''>step</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>employing</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>search</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>(GP)</span> <span style=''>to</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>this</span> <span style=''>does</span> <span style=''>not</span> <span style=''>scale</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style=''>O(N3)</span> <span style=''>running</span> <span style=''>time</span> <span style=''>for</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>Scalable</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Composition</span> <span style=''>(SKC)</span> <span style=''>a</span> <span style=''>scalable</span> <span style=''>kernel</span> <span style=''>search</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>extends</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistician</span> <span style=''>to</span> <span style=''>bigger</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>In</span> <span style=''>doing</span> <span style=''>so</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>cheap</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>GP</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>that</span> <span style=''>sandwiches</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likel ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Outlier</span> <span style=''>Robust</span> <span style='background-color:rgba(255, 0, 0, 0.5029585798816567);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>give</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>linear</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(255, 0, 0, 0.5029585798816567);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resilient</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corruptions</span> <span style=''>in</span> <span style=''>both</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>labels</span> <span style=''>Given</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3023255813953488);'>sufficiently</span> <span style=''>large</span> <span style=''>(polynomial</span> <span style=''>size)</span> <span style=''>training</span> <span style=''>set</span> <span style=''>drawn</span> <span style=''>iid</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>D</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsequently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style=''>on</span> <span style=''>some</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>points</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>outputs</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>function</span> <span style=''>whose</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>is</span> <span style=''>close</span> <span style=''>to</span> <span style=''>the</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style=''>best</span> <span style=''>fitting</span> <span style=''>linear</span> <span style=''>function</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>D</span> <span style=''>assuming</span> <span style=''>that</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>D</span> <span style=''>over</span> <span style=''>the</span> <span style=''>input</span> <span style=''>space</span> <span style=''>is</span> <span style=''>emphcertifiably</span> <span style=''>hypercontractive</span> <span style=''>This</span> <span style=''>natural</span> <span style=''>property</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfied</span> <span style=''>by</span> <span style=''>many</span> <span style=''>well</span> <span style=''>studied</span> <span style='background-color:rgba(255, 0, 0, 0.3767705382436261);'>distributions</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Gaussian</span> <span style=''>strongly</span> <span style=''>log</span> <span style=''>concave</span> <span style='background-color:rgba(255, 0, 0, 0.3767705382436261);'>distributions</span> <span style=''>and</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Weighting</span> <span style=''>of</span> <span style=''>Multi</span> <span style=''>View</span> <span style=''>Data</span> <span style=''>with</span> <span style=''>Low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Hidden</span> <span style=''>States</span> <br/><br/><span style=''>In</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processing</span> <span style=''>(NLP)</span> <span style=''>tasks</span> <span style=''>data</span> <span style=''>often</span> <span style=''>has</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>First</span> <span style=''>data</span> <span style=''>can</span> <span style=''>be</span> <span style=''>chopped</span> <span style=''>into</span> <span style=''>multi</span> <span style=''>views</span> <span style=''>which</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>purposes</span> <span style=''>For</span> <span style=''>example</span> <span style=''>in</span> <span style=''>topic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>every</span> <span style=''>paper</span> <span style=''>can</span> <span style=''>be</span> <span style=''>chopped</span> <span style=''>into</span> <span style=''>the</span> <span style=''>title</span> <span style=''>the</span> <span style=''>main</span> <span style=''>text</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>references</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style=''>common</span> <span style=''>that</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style=''>views</span> <span style=''>are</span> <span style=''>less</span> <span style=''>noisier</span> <span style=''>than</span> <span style=''>other</span> <span style=''>views</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>Second</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>are</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>while</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>rare</span> <span style=''>For</span> <span style=''>example</span> <span style=''>articles</span> <span style=''>occurred</span> <span style=''>on</span> <span style=''>New</span> <span style=''>York</span> <span style=''>Times</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>10</span> <span style=''>years</span> <span style=''>are</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>grab</span> <span style=''>but</span> <span style=''>having</span> <span style=''>them</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classified</span> <span style=''>as</span> <span style=''>Politics</span> <span style=''>Finance</span> <span style=''>or</span> <span style=''>Sports</span> <span style=''>need</span> <span style=''>human</span> <span style=''>labor</span> <span style=''>Hence</span> <span style=''>less</span> <span style=''>noisy</span> <span s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13366690493209435)
# 	evaluation (0.09756969263759828)
# 	information (0.2523230879199428)
# 	knowledge (0.12544674767691208)
# 	architecture (0.08934953538241601)
# 	segmentation (0.06719085060757685)
# 	different (0.27162258756254465)
# 	detection (0.12258756254467476)
# 	recognition (0.12544674767691208)
# 	convolutional (0.13116511794138672)
#
# Some Statistics words are:
# 	variational (0.0984015984015984)
# 	stochastic (0.12987012987012986)
# 	algorithm (0.3901098901098901)
# 	estimation (0.16883116883116883)
# 	statistical (0.15634365634365635)
# 	theoretical (0.15684315684315683)
# 	distribution (0.18731268731268733)
# 	dimensional (0.18581418581418582)
# 	inference (0.1953046953046953)
# 	regression (0.1903096903096903)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="317db735-ce00-4da8-9663-6b804e482323" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("317db735-ce00-4da8-9663-6b804e482323")) {                    Plotly.newPlot(                        "317db735-ce00-4da8-9663-6b804e482323",                        [{"x":["applications","classifying","promising","potential","represented","viability","invariant","experimental","dimensions","supervised","different","classifier","including","differences","dimensionality","mathematically","similarity","advantage","functions","significantly","evaluation","experiments","retrieval","generalization","dimensional","efficient","linearity","formulations","demonstrate","capability","performance","inference","outperforms","especially","encouraging","achieving","typically","precision","literature","demonstrated","magnitude","prototype","presented","philosophical","formalized","nonlinear","increasing","concentration","treatment","constructs","evolution","description","mathematical","autonomous","prototyping","structures","consideration","computational","differential","investigation","developed","implement","recognition","alternative","automatic","equations","application","programming","intuitive","extension","adaptation","described","discussed","describes","probabilistic","probabilities","lauritzen","spiegelhalter","resulting","partially","validating","effectiveness","labelling","theoretic","suboptimal","automated","automatically","improvement","confidence","annotator","substantially","reductions","validates","according","classification","reduction","generated","maximized","documents","implemented","information","instances","performed","architecture","comparison","addressing","integrating","representation","commonsense","relations","reasoning","qualitative","contemporary","constraints","satisfiability","currently","geographic","geometric","systematic","empirically","cognitive","polynomial","requirement","publication","monotonic","formalise","arithmetic","modelling","therefore","predictions","participants","additional","objective","solutions","positives","tomography","available","algorithms","validation","originally","annotated","convolutional","development","framework","challenge","excellent","candidates","detection","sensitivity","classified","combination","comparative","highlights","pulmonary","reference","algorithm","individual","investigated","combining","regularization","eigenvalues","generalized","associated","furthermore","techniques","localization","optimality","convergence","characterized","constantly","circumvent","approaches","considerably","themselves","artificial","filtering","specifically","neighbors","simplistic","dependencies","influence","experience","heterogeneous","conjunction","intelligent","prediction","probability","distribution","transitions","arbitrary","controlling","conditional","durations","synthetic","vehicular","predicting","transportation","parameters","conditions","influences","transparent","electronic","structure","underlying","transfers","discharge","intervention","irregular","unplanned","engineering","traditional","important","detecting","bottleneck","visualization","meaningful","predictive","separated","readmission","transforms","inspection","questions","understanding","frameworks","statistical","applicable","attention","distribute","researchers","principles","communication","distilled","traditionally","algorithmic","characteristics","communicated","opportunities","continuum","computation","strategies","generally","successful","industrial","guarantees","analytics","theoretical","significant","practitioners","supported","distributed","harnessed","architectures","extracted","validated","fluctuations","interference","m ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unplanned
# 	dependences
# 	diagonalization
# 	decorrelation
# 	particulars
# 	determinantal
# 	intuitions
# 	measurability
# 	covariates
# 	misspecified
# 	decoupled
# 	datapoints
# 	inductively
# 	nucleotide
# 	celebrated
# 	disclosure
# 	rectifier
# 	oftentimes
# 	deviating
# 	stationarity
# Some words which never appear in Statistics papers:
# 	philosophical
# 	spiegelhalter
# 	annotator
# 	validates
# 	commonsense
# 	formalise
# 	vehicular
# 	denoisers
# 	deblurring
# 	inaccuracies
# 	biophysical
# 	mammography
# 	weightings
# 	supervisions
# 	microscope
# 	surpassed
# 	corroborated
# 	metastases
# 	computerized
# 	prefetching

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0750307503075034e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
